# %% [markdown]
# # Introduction to image segmentation

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a simple dataset
class SimpleDataset(Dataset):
    def __init__(self, size=100, image_size=128):
        self.size = size
        self.image_size = image_size

    def __len__(self):
        return self.size

    def __getitem__(self, idx):
        # Create a random input image
        center_x = np.random.randint(0, self.image_size)
        center_y = np.random.randint(0, self.image_size)
        radius = np.random.randint(10, self.image_size // 4)

        x, y = torch.meshgrid(torch.arange(self.image_size), torch.arange(self.image_size))
        distance = ((x - center_x)**2 + (y - center_y)**2).sqrt()
        target = (distance < radius).float().unsqueeze(0)

        # Add noise to the target to create the input image
        noise = torch.randn(1, self.image_size, self.image_size) * 0.8
        input_image = target + noise

        return input_image, target

# %%
import matplotlib.pyplot as plt
# Create an instance of the dataset
dataset = SimpleDataset(size=1, image_size=128)

# Get a sample from the dataset
for i in range(3):
    input_image, target = dataset[i]
    # Visualize the input image
    plt.figure(figsize=(4, 2))
    plt.subplot(1, 2, 1)
    plt.imshow(input_image[0], cmap='gray')
    plt.title('Input Image')
    # plt.show()
    # Visualize the target image
    plt.subplot(1, 2, 2)
    plt.imshow(target[0], cmap='gray')
    plt.title('Target Image')
    plt.show()
    # break
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %% [markdown]
# # Simple image to image

# %% [markdown]
# [Autoencoder](https://blog.paperspace.com/convolutional-autoencoder/)

# %%
# Define a simple model with ConvTranspose2d
class SimpleAutoencoder(nn.Module):
    def __init__(self):
        super().__init__()
        # Conv layer to reduce spatial dimensions
        self.conv = nn.Conv2d(in_channels=1, out_channels=1, kernel_size=4, stride=2, padding=1)
        # ConvTranspose2d layer to increase spatial dimensions
        self.conv_transpose = nn.ConvTranspose2d(in_channels=1, out_channels=1, kernel_size=4, stride=2, padding=1)

    def forward(self, x):
        # Downsample
        x = self.conv(x)
        # Upsample
        x = self.conv_transpose(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dataset = SimpleDataset()
train_loader = DataLoader(dataset, batch_size=16, shuffle=True)

# %%
# Initialize the model, loss function, and optimizer
model = SimpleAutoencoder().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# Training loop
num_epochs = 150
for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for batch_idx, (data, _) in enumerate(train_loader):
        data = data.to(device)
        optimizer.zero_grad()
        outputs = model(data)
        loss = criterion(outputs, data)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        if (batch_idx + 1) % 100 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx+1}/{len(train_loader)}], Loss: {loss.item():.4f}')

    avg_loss = train_loss / len(train_loader)
    print(f'Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_loss:.4f}')
# Out:
# Epoch [1/150], Average Loss: 0.7562
# Epoch [2/150], Average Loss: 0.7472
# Epoch [3/150], Average Loss: 0.7305
# Epoch [4/150], Average Loss: 0.7257
# Epoch [5/150], Average Loss: 0.7130
# Epoch [6/150], Average Loss: 0.7044
# Epoch [7/150], Average Loss: 0.7004
# Epoch [8/150], Average Loss: 0.6961
# Epoch [9/150], Average Loss: 0.6885
# Epoch [10/150], Average Loss: 0.6776
# Epoch [11/150], Average Loss: 0.6609
# Epoch [12/150], Average Loss: 0.6656
# Epoch [13/150], Average Loss: 0.6554
# Epoch [14/150], Average Loss: 0.6475
# Epoch [15/150], Average Loss: 0.6348
# Epoch [16/150], Average Loss: 0.6244
# Epoch [17/150], Average Loss: 0.6150
# Epoch [18/150], Average Loss: 0.6169
# Epoch [19/150], Average Loss: 0.6040
# Epoch [20/150], Average Loss: 0.5885
# Epoch [21/150], Average Loss: 0.5803
# Epoch [22/150], Average Loss: 0.5704
# Epoch [23/150], Average Loss: 0.5627
# Epoch [24/150], Average Loss: 0.5547
# Epoch [25/150], Average Loss: 0.5455
# Epoch [26/150], Average Loss: 0.5391
# Epoch [27/150], Average Loss: 0.5339
# Epoch [28/150], Average Loss: 0.5285
# Epoch [29/150], Average Loss: 0.5232
# Epoch [30/150], Average Loss: 0.5184
# Epoch [31/150], Average Loss: 0.5148
# Epoch [32/150], Average Loss: 0.5133
# Epoch [33/150], Average Loss: 0.5101
# Epoch [34/150], Average Loss: 0.5063
# Epoch [35/150], Average Loss: 0.5058
# Epoch [36/150], Average Loss: 0.5028
# Epoch [37/150], Average Loss: 0.5021
# Epoch [38/150], Average Loss: 0.5012
# Epoch [39/150], Average Loss: 0.5001
# Epoch [40/150], Average Loss: 0.4988
# Epoch [41/150], Average Loss: 0.4960
# Epoch [42/150], Average Loss: 0.4945
# Epoch [43/150], Average Loss: 0.4937
# Epoch [44/150], Average Loss: 0.4943
# Epoch [45/150], Average Loss: 0.4945
# Epoch [46/150], Average Loss: 0.4914
# Epoch [39/50], Average Loss: 0.6439
# Epoch [40/50], Average Loss: 0.6434
# Epoch [41/50], Average Loss: 0.6434
# Epoch [42/50], Average Loss: 0.6430
# Epoch [43/50], Average Loss: 0.6433
# Epoch [44/50], Average Loss: 0.6428
# Epoch [45/50], Average Loss: 0.6434
# Epoch [46/50], Average Loss: 0.6409
# Epoch [47/50], Average Loss: 0.6416
# Epoch [48/50], Average Loss: 0.6418
# Epoch [49/50], Average Loss: 0.6416
# Epoch [50/50], Average Loss: 0.6441

# %%
# Visualize results
model.eval()
with torch.no_grad():
    inputs, targets = next(iter(train_loader))
    inputs, targets = inputs.to(device), targets.to(device)
    outputs = model(inputs)
    outputs = torch.sigmoid(outputs)

    fig, axes = plt.subplots(3, 4, figsize=(15, 10))
    for i in range(4):
        axes[0, i].imshow(inputs[i, 0].cpu(), cmap='gray')
        axes[0, i].set_title('Input')
        axes[1, i].imshow(targets[i, 0].cpu(), cmap='gray')
        axes[1, i].set_title('Target')
        axes[2, i].imshow(outputs[i, 0].cpu(), cmap='gray')
        axes[2, i].set_title('Prediction')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # U-Net architecture
# [Pytorch-UNet](https://github.com/milesial/Pytorch-UNet)

# %%
# Define the U-Net architecture
class UNet(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(UNet, self).__init__()

        # Encoder (downsampling)
        self.enc1 = self.conv_block(in_channels, 64)
        self.enc2 = self.conv_block(64, 128)
        self.enc3 = self.conv_block(128, 256)
        self.enc4 = self.conv_block(256, 512)

        # Decoder (upsampling)
        self.dec1 = self.upconv_block(512, 256)
        self.dec2 = self.upconv_block(512, 128)
        self.dec3 = self.upconv_block(256, 64)
        self.final = nn.Conv2d(128, out_channels, kernel_size=1)

    def conv_block(self, in_ch, out_ch):
        return nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.ReLU(inplace=True)
        )

    def upconv_block(self, in_ch, out_ch):
        return nn.Sequential(
            nn.ConvTranspose2d(in_ch, out_ch, 2, stride=2),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        # Encoder
        e1 = self.enc1(x)
        e2 = self.enc2(nn.functional.max_pool2d(e1, 2))
        e3 = self.enc3(nn.functional.max_pool2d(e2, 2))
        e4 = self.enc4(nn.functional.max_pool2d(e3, 2))

        # Decoder
        d1 = self.dec1(e4)
        d2 = self.dec2(torch.cat([d1, e3], dim=1))
        d3 = self.dec3(torch.cat([d2, e2], dim=1))
        out = self.final(torch.cat([d3, e1], dim=1))

        return out

# %%
# Set up the model, loss function, and optimizer

model = UNet(in_channels=1, out_channels=1).to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters())

# Create the dataset and data loader
dataset = SimpleDataset()
dataloader = DataLoader(dataset, batch_size=16, shuffle=True)

# %%
# Training loop
num_epochs = 50
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    for inputs, targets in dataloader:
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss/len(dataloader):.4f}")

# Visualize results
model.eval()
with torch.no_grad():
    inputs, targets = next(iter(dataloader))
    inputs, targets = inputs.to(device), targets.to(device)
    outputs = model(inputs)
    outputs = torch.sigmoid(outputs)

    fig, axes = plt.subplots(3, 4, figsize=(15, 10))
    for i in range(4):
        axes[0, i].imshow(inputs[i, 0].cpu(), cmap='gray')
        axes[0, i].set_title('Input')
        axes[1, i].imshow(targets[i, 0].cpu(), cmap='gray')
        axes[1, i].set_title('Target')
        axes[2, i].imshow(outputs[i, 0].cpu(), cmap='gray')
        axes[2, i].set_title('Prediction')

    plt.tight_layout()
    plt.show()
# Out:
# Epoch 1/50, Loss: 0.4668
# Epoch 2/50, Loss: 0.2019
# Epoch 3/50, Loss: 0.0656
# Epoch 4/50, Loss: 0.0370
# Epoch 5/50, Loss: 0.0273
# Epoch 6/50, Loss: 0.0220
# Epoch 7/50, Loss: 0.0126
# Epoch 8/50, Loss: 0.0105
# Epoch 9/50, Loss: 0.0085
# Epoch 10/50, Loss: 0.0083
# Epoch 11/50, Loss: 0.0079
# Epoch 12/50, Loss: 0.0076
# Epoch 13/50, Loss: 0.0073
# Epoch 14/50, Loss: 0.0075
# Epoch 15/50, Loss: 0.0071
# Epoch 16/50, Loss: 0.0073
# Epoch 17/50, Loss: 0.0067
# Epoch 18/50, Loss: 0.0068
# Epoch 19/50, Loss: 0.0073
# Epoch 20/50, Loss: 0.0069
# Epoch 21/50, Loss: 0.0070
# Epoch 22/50, Loss: 0.0066
# Epoch 23/50, Loss: 0.0066
# Epoch 24/50, Loss: 0.0067
# Epoch 25/50, Loss: 0.0062
# Epoch 26/50, Loss: 0.0058
# Epoch 27/50, Loss: 0.0065
# Epoch 28/50, Loss: 0.0063
# Epoch 29/50, Loss: 0.0063
# Epoch 30/50, Loss: 0.0060
# Epoch 31/50, Loss: 0.0062
# Epoch 32/50, Loss: 0.0055
# Epoch 33/50, Loss: 0.0066
# Epoch 34/50, Loss: 0.0062
# Epoch 35/50, Loss: 0.0055
# Epoch 36/50, Loss: 0.0058
# Epoch 37/50, Loss: 0.0054
# Epoch 38/50, Loss: 0.0054
# Epoch 39/50, Loss: 0.0059
# Epoch 40/50, Loss: 0.0058
# Epoch 41/50, Loss: 0.0055
# Epoch 42/50, Loss: 0.0053
# Epoch 43/50, Loss: 0.0056
# Epoch 44/50, Loss: 0.0051
# Epoch 45/50, Loss: 0.0057
# Epoch 46/50, Loss: 0.0054
# Epoch 47/50, Loss: 0.0051
# Epoch 48/50, Loss: 0.0048
# Epoch 49/50, Loss: 0.0051
# Epoch 50/50, Loss: 0.0055

# %%
# !pip install torchviz

# %%
# # Visualize the model architecture
# from torchviz import make_dot

# x = torch.randn(1, 1, 128, 128).to(device)
# y = model(x)
# dot = make_dot(y.mean(), params=dict(model.named_parameters()))
# dot.render("unet_architecture", format="png")
# Out:
# 'unet_architecture.png'

# %% [markdown]
# # Multiple object

# %%
class SimpleDataset(Dataset):
    def __init__(self, size=100, image_size=128):
        self.size = size
        self.image_size = image_size

    def __len__(self):
        return self.size

    def __getitem__(self, idx):
        # Create a blank canvas for target
        target = torch.zeros(2, self.image_size, self.image_size)

        # Generate circle
        center_x = np.random.randint(0, self.image_size)
        center_y = np.random.randint(0, self.image_size)
        radius = np.random.randint(10, self.image_size // 6)
        x, y = torch.meshgrid(torch.arange(self.image_size), torch.arange(self.image_size))
        distance = ((x - center_x)**2 + (y - center_y)**2).sqrt()
        target[0] = (distance < radius).float()

        # Generate rectangle
        rect_x = np.random.randint(0, self.image_size - self.image_size // 4)
        rect_y = np.random.randint(0, self.image_size - self.image_size // 4)
        rect_w = np.random.randint(self.image_size // 8, self.image_size // 4)
        rect_h = np.random.randint(self.image_size // 8, self.image_size // 4)
        target[1, rect_x:rect_x+rect_w, rect_y:rect_y+rect_h] = 1

        # Combine circle and rectangle
        combined_target = (target.sum(dim=0) > 0).float().unsqueeze(0)

        # Add noise to create the input image
        noise = torch.randn(1, self.image_size, self.image_size) * 0.5
        input_image = combined_target + noise

        return input_image, target

# %%
# Define the U-Net architecture (unchanged)
class UNet(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(UNet, self).__init__()

        # Encoder (downsampling)
        self.enc1 = self.conv_block(in_channels, 64)
        self.enc2 = self.conv_block(64, 128)
        self.enc3 = self.conv_block(128, 256)
        self.enc4 = self.conv_block(256, 512)

        # Decoder (upsampling)
        self.dec1 = self.upconv_block(512, 256)
        self.dec2 = self.upconv_block(512, 128)
        self.dec3 = self.upconv_block(256, 64)
        self.final = nn.Conv2d(128, out_channels, kernel_size=1)

    def conv_block(self, in_ch, out_ch):
        return nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.ReLU(inplace=True)
        )

    def upconv_block(self, in_ch, out_ch):
        return nn.Sequential(
            nn.ConvTranspose2d(in_ch, out_ch, 2, stride=2),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        # Encoder
        e1 = self.enc1(x)
        e2 = self.enc2(nn.functional.max_pool2d(e1, 2))
        e3 = self.enc3(nn.functional.max_pool2d(e2, 2))
        e4 = self.enc4(nn.functional.max_pool2d(e3, 2))

        # Decoder
        d1 = self.dec1(e4)
        d2 = self.dec2(torch.cat([d1, e3], dim=1))
        d3 = self.dec3(torch.cat([d2, e2], dim=1))
        out = self.final(torch.cat([d3, e1], dim=1))

        return out

# %%
# Set up the model, loss function, and optimizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = UNet(in_channels=1, out_channels=2).to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters())

# Create the dataset and data loader
dataset = SimpleDataset()
dataloader = DataLoader(dataset, batch_size=16, shuffle=True)

# Training loop
num_epochs = 50
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    for inputs, targets in dataloader:
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss/len(dataloader):.4f}")
# Out:
# Epoch 1/50, Loss: 0.6217
# Epoch 2/50, Loss: 0.4672
# Epoch 3/50, Loss: 0.2521
# Epoch 4/50, Loss: 0.1139
# Epoch 5/50, Loss: 0.0834
# Epoch 6/50, Loss: 0.0680
# Epoch 7/50, Loss: 0.0654
# Epoch 8/50, Loss: 0.0592
# Epoch 9/50, Loss: 0.0535
# Epoch 10/50, Loss: 0.0545
# Epoch 11/50, Loss: 0.0520
# Epoch 12/50, Loss: 0.0530
# Epoch 13/50, Loss: 0.0529
# Epoch 14/50, Loss: 0.0548
# Epoch 15/50, Loss: 0.0520
# Epoch 16/50, Loss: 0.0513
# Epoch 17/50, Loss: 0.0489
# Epoch 18/50, Loss: 0.0517
# Epoch 19/50, Loss: 0.0531
# Epoch 20/50, Loss: 0.0486
# Epoch 21/50, Loss: 0.0523
# Epoch 22/50, Loss: 0.0495
# Epoch 23/50, Loss: 0.0579
# Epoch 24/50, Loss: 0.0530
# Epoch 25/50, Loss: 0.0514
# Epoch 26/50, Loss: 0.0534
# Epoch 27/50, Loss: 0.0507
# Epoch 28/50, Loss: 0.0527
# Epoch 29/50, Loss: 0.0502
# Epoch 30/50, Loss: 0.0522
# Epoch 31/50, Loss: 0.0527
# Epoch 32/50, Loss: 0.0503
# Epoch 33/50, Loss: 0.0510
# Epoch 34/50, Loss: 0.0485
# Epoch 35/50, Loss: 0.0487
# Epoch 36/50, Loss: 0.0409
# Epoch 37/50, Loss: 0.0344
# Epoch 38/50, Loss: 0.0596
# Epoch 39/50, Loss: 0.0466
# Epoch 40/50, Loss: 0.0387
# Epoch 41/50, Loss: 0.0289
# Epoch 42/50, Loss: 0.0204
# Epoch 43/50, Loss: 0.0216
# Epoch 44/50, Loss: 0.0150
# Epoch 45/50, Loss: 0.0128
# Epoch 46/50, Loss: 0.0093
# Epoch 47/50, Loss: 0.0075
# Epoch 48/50, Loss: 0.0089
# Epoch 49/50, Loss: 0.0080
# Epoch 50/50, Loss: 0.0086

# %%
# Visualize results
model.eval()
with torch.no_grad():
    inputs, targets = next(iter(dataloader))
    inputs, targets = inputs.to(device), targets.to(device)
    outputs = model(inputs)
    outputs = torch.sigmoid(outputs)

    fig, axes = plt.subplots(5, 4, figsize=(15, 15))
    for i in range(4):
        axes[0, i].imshow(inputs[i, 0].cpu(), cmap='gray')
        axes[0, i].set_title('Input')
        axes[0, i].axis('off')

        axes[1, i].imshow(targets[i, 0].cpu(), cmap='gray')
        axes[1, i].set_title('Target (Circle)')
        axes[1, i].axis('off')

        axes[2, i].imshow(targets[i, 1].cpu(), cmap='gray')
        axes[2, i].set_title('Target (Rectangle)')
        axes[2, i].axis('off')

        axes[3, i].imshow(outputs[i, 0].cpu(), cmap='gray')
        axes[3, i].set_title('Prediction (Circle)')
        axes[3, i].axis('off')

        axes[4, i].imshow(outputs[i, 1].cpu(), cmap='gray')
        axes[4, i].set_title('Prediction (Rectangle)')
        axes[4, i].axis('off')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Hand on
#
# Revise the code to be able to segment 4 objects per image using U-Net.

# %% [markdown]
# # High performance and well known model
# https://pytorch.org/vision/stable/models.html
#
# https://universe.roboflow.com/
